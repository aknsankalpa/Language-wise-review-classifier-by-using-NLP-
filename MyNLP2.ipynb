# %%
print("Setting up enhanced language detection...")

# Import all available libraries
import sys

# Try importing multiple libraries
try:
    import pycld2 as cld2
    cld2_available = True
    print("✓ CLD2 loaded")
except:
    cld2_available = False
    print("✗ CLD2 not available")

try:
    from langdetect import detect, detect_langs
    from langdetect.lang_detect_exception import LangDetectException
    langdetect_available = True
    print("✓ langdetect loaded")
except:
    langdetect_available = False
    print("✗ langdetect not available")

try:
    import langid
    langid_available = True
    print("✓ langid loaded")
except:
    langid_available = False
    print("✗ langid not available")

print(f"\nActive detectors: {sum([cld2_available, langdetect_available, langid_available])}/3")
print("="*80 + "\n")
# Out:
# Setting up enhanced language detection...
# ✓ CLD2 loaded
# ✓ langdetect loaded
# ✓ langid loaded
#
# Active detectors: 3/3
# ================================================================================

# %%
def detect_language_enhanced(text, min_confidence=70):
    
    results = []
    
    # Method 1: CLD2 (Best for Unicode scripts like Sinhala, Tamil)
    if cld2_available:
        try:
            isReliable, textBytesFound, details = cld2.detect(text)
            if details and len(details) > 0:
                results.append({
                    'library': 'cld2',
                    'language': details[0][0],
                    'code': details[0][1],
                    'confidence': details[0][2],
                    'reliable': isReliable,
                    'weight': 3  # Higher weight for CLD2
                })
        except:
            pass
    
    # Method 2: langdetect (Good for European languages like Spanish)
    if langdetect_available:
        try:
            lang_code = detect(text)
            langs = detect_langs(text)
            confidence = langs[0].prob * 100 if langs else 0
            
            results.append({
                'library': 'langdetect',
                'language': get_language_name(lang_code),
                'code': lang_code,
                'confidence': confidence,
                'reliable': confidence > 90,
                'weight': 2
            })
        except LangDetectException:
            pass
        except:
            pass
    
    # Method 3: langid (Fast and reliable)
    if langid_available:
        try:
            lang_code, confidence_raw = langid.classify(text)
            confidence = confidence_raw * 100 if confidence_raw > 0 else confidence_raw
            
            results.append({
                'library': 'langid',
                'language': get_language_name(lang_code),
                'code': lang_code,
                'confidence': abs(confidence),
                'reliable': abs(confidence) > 0,
                'weight': 2
            })
        except:
            pass
    
    # If no results, return Unknown
    if not results:
        return {
            'language': 'Unknown',
            'code': 'unknown',
            'confidence': 0,
            'reliable': False,
            'method': 'none'
        }
    
    # Voting system: Prioritize results with higher confidence and weight
    # Sort by: reliability, confidence, and weight
    results.sort(key=lambda x: (x['reliable'], x['confidence'] * x['weight']), reverse=True)
    
    best_result = results[0]
    
    # Check if we have consensus among libraries
    if len(results) > 1:
        # If multiple libraries agree on the language, increase confidence
        languages_detected = [r['language'].upper() for r in results]
        most_common = max(set(languages_detected), key=languages_detected.count)
        
        if languages_detected.count(most_common) > 1:
            # Multiple libraries agree - boost confidence
            for r in results:
                if r['language'].upper() == most_common:
                    best_result = r
                    best_result['confidence'] = min(99, best_result['confidence'] * 1.1)
                    best_result['method'] = 'consensus'
                    break
    
    best_result['method'] = best_result.get('method', best_result['library'])
    return best_result

def get_language_name(code):
    """Convert language code to full name"""
    language_names = {
        'af': 'Afrikaans', 'ar': 'Arabic', 'bg': 'Bulgarian', 'bn': 'Bengali',
        'ca': 'Catalan', 'cs': 'Czech', 'cy': 'Welsh', 'da': 'Danish',
        'de': 'German', 'el': 'Greek', 'en': 'English', 'es': 'Spanish',
        'et': 'Estonian', 'fa': 'Persian', 'fi': 'Finnish', 'fr': 'French',
        'gu': 'Gujarati', 'he': 'Hebrew', 'hi': 'Hindi', 'hr': 'Croatian',
        'hu': 'Hungarian', 'id': 'Indonesian', 'it': 'Italian', 'ja': 'Japanese',
        'kn': 'Kannada', 'ko': 'Korean', 'lt': 'Lithuanian', 'lv': 'Latvian',
        'mk': 'Macedonian', 'ml': 'Malayalam', 'mr': 'Marathi', 'ne': 'Nepali',
        'nl': 'Dutch', 'no': 'Norwegian', 'pa': 'Punjabi', 'pl': 'Polish',
        'pt': 'Portuguese', 'ro': 'Romanian', 'ru': 'Russian', 'sk': 'Slovak',
        'sl': 'Slovenian', 'so': 'Somali', 'sq': 'Albanian', 'sv': 'Swedish',
        'sw': 'Swahili', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai',
        'tl': 'Tagalog', 'tr': 'Turkish', 'uk': 'Ukrainian', 'ur': 'Urdu',
        'vi': 'Vietnamese', 'zh': 'Chinese', 'zh-cn': 'Chinese', 'zh-tw': 'Chinese',
        'si': 'Sinhala', 'SINHALESE': 'Sinhala', 'TAMIL': 'Tamil', 
        'SPANISH': 'Spanish', 'ENGLISH': 'English', 'FRENCH': 'French'
    }
    
    # Handle uppercase names from CLD2
    if code.upper() in language_names.values():
        return code.title()
    
    return language_names.get(code.lower(), code.upper())

print("✓ Enhanced detection system ready!")
# Out:
# ✓ Enhanced detection system ready!

# %%
class EnhancedReviewAnalyzer:
    """Improved Review Analyzer with better language detection"""
    
    def __init__(self):
        self.language_sentiment = {}
        self.detection_details = []
    
    def analyze_reviews(self, reviews):
        """Analyze reviews with enhanced language detection"""
        all_results = []
        
        for review in reviews:
            # Use enhanced detection
            detection = detect_language_enhanced(review['text'])
            language = detection['language']
            
            # Initialize language category if needed
            if language not in self.language_sentiment:
                self.language_sentiment[language] = {
                    'reviews': [],
                    'avg_rating': 0,
                    'count': 0,
                    'total_confidence': 0
                }
            
            # Add review to language category
            self.language_sentiment[language]['reviews'].append(review)
            self.language_sentiment[language]['count'] += 1
            self.language_sentiment[language]['total_confidence'] += detection['confidence']
            
            # Store detailed result
            result = {
                'text': review['text'][:50] + '...' if len(review['text']) > 50 else review['text'],
                'full_text': review['text'],
                'language': language,
                'rating': review.get('rating', 0),
                'confidence': detection['confidence'],
                'detection_method': detection.get('method', 'unknown'),
                'reliable': detection.get('reliable', False)
            }
            
            all_results.append(result)
            self.detection_details.append(result)
        
        # Calculate average ratings and confidence
        for lang in self.language_sentiment:
            reviews = self.language_sentiment[lang]['reviews']
            count = self.language_sentiment[lang]['count']
            if reviews and count > 0:
                avg_rating = sum(r.get('rating', 0) for r in reviews) / len(reviews)
                self.language_sentiment[lang]['avg_rating'] = avg_rating
                
                avg_confidence = self.language_sentiment[lang]['total_confidence'] / count
                self.language_sentiment[lang]['avg_confidence'] = avg_confidence
        
        return self.language_sentiment, all_results
    
    def print_detailed_report(self):
        """Print comprehensive analysis report"""
        total_reviews = sum(data['count'] for data in self.language_sentiment.values())
        
        print("\n" + "="*80)
        print("ENHANCED PRODUCT REVIEW ANALYSIS")
        print("="*80)
        print(f"Total reviews analyzed: {total_reviews}")
        print(f"Languages detected: {len(self.language_sentiment)}")
        print("="*80 + "\n")
        
        # Sort languages by number of reviews
        sorted_langs = sorted(
            self.language_sentiment.items(), 
            key=lambda x: x[1]['count'], 
            reverse=True
        )
        
        for lang, data in sorted_langs:
            percentage = (data['count'] / total_reviews) * 100
            
            print(f"{lang.upper()}")
            print(f"  📊 Reviews: {data['count']} ({percentage:.1f}% of total)")
            print(f"  ⭐ Average rating: {data['avg_rating']:.2f}/5.0")
            print(f"  🎯 Detection confidence: {data['avg_confidence']:.1f}%")
            print(f"  📝 Sample reviews:")
            
            # Show 2 sample reviews
            for i, review in enumerate(data['reviews'][:2], 1):
                text_preview = review['text'][:60] + '...' if len(review['text']) > 60 else review['text']
                print(f"     {i}. \"{text_preview}\" - Rating: {review.get('rating', 'N/A')}/5")
            
            print()
        
        return sorted_langs
    
    def get_low_confidence_reviews(self, threshold=80):
        """Identify reviews with low detection confidence"""
        low_conf = [
            detail for detail in self.detection_details 
            if detail['confidence'] < threshold
        ]
        
        if low_conf:
            print(f"\n⚠️  Reviews with confidence below {threshold}%:")
            print("-"*80)
            for detail in low_conf:
                print(f"Text: {detail['text']}")
                print(f"  Detected as: {detail['language']} ({detail['confidence']:.1f}%)")
                print(f"  Method: {detail['detection_method']}")
                print()
        else:
            print(f"\n✓ All reviews detected with confidence above {threshold}%")
        
        return low_conf
    
    def compare_detection_methods(self, text):
        """Show how each library detects a specific text"""
        print(f"\nDetection Method Comparison")
        print(f"Text: \"{text}\"")
        print("-"*80)
        
        # CLD2
        if cld2_available:
            try:
                isReliable, textBytesFound, details = cld2.detect(text)
                if details:
                    print(f"CLD2: {details[0][0]} (confidence: {details[0][2]}%, reliable: {isReliable})")
            except Exception as e:
                print(f"CLD2: Error - {str(e)}")
        
        # langdetect
        if langdetect_available:
            try:
                lang = detect(text)
                langs = detect_langs(text)
                print(f"langdetect: {get_language_name(lang)} (confidence: {langs[0].prob*100:.1f}%)")
            except Exception as e:
                print(f"langdetect: Error - {str(e)}")
        
        # langid
        if langid_available:
            try:
                lang, conf = langid.classify(text)
                print(f"langid: {get_language_name(lang)} (confidence: {abs(conf*100):.1f}%)")
            except Exception as e:
                print(f"langid: Error - {str(e)}")
        
        # Final enhanced result
        final = detect_language_enhanced(text)
        print(f"\n→ FINAL RESULT: {final['language']} (confidence: {final['confidence']:.1f}%)")
        print(f"  Method used: {final.get('method', 'unknown')}")
        print("-"*80)

print("✓ Enhanced Review Analyzer ready!")
# Out:
# ✓ Enhanced Review Analyzer ready!

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\SANKALPA\\Downloads\\train.csv')

# %%
import time
import pycld2 as cld2
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
import multiprocessing as mp
from functools import lru_cache
import pandas as pd

# %%
def split_into_batches(data, batch_size):
    """Split data into batches for parallel processing"""
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %%
def detect_language_fast(text):
    """
    Fast detection using only CLD2 (fastest and most accurate)
    Uses caching to avoid re-processing identical reviews
    """
    if not text or len(text.strip()) < 3:
        return {
            'language': 'Unknown',
            'code': 'unknown',
            'confidence': 0,
            'reliable': False
        }
    
    try:
        # CLD2 is the fastest and works well for most languages
        isReliable, textBytesFound, details = cld2.detect(text)
        if details and len(details) > 0:
            return {
                'language': details[0][0],
                'code': details[0][1],
                'confidence': details[0][2],
                'reliable': isReliable
            }
    except:
        pass
    
    # Fallback for very short or problematic text
    return {
        'language': 'Unknown',
        'code': 'unknown',
        'confidence': 0,
        'reliable': False
    }

# %%
def process_review_batch(reviews_batch):
    """Process a batch of reviews (for parallel processing)"""
    results = []
    for review in reviews_batch:
        text = review.get('text', '')
        rating = review.get('rating', 0)
        
        detection = detect_language_fast(text)
        
        results.append({
            'text': text[:50] + '...' if len(text) > 50 else text,
            'full_text': text,
            'language': detection['language'],
            'code': detection['code'],
            'rating': rating,
            'confidence': detection['confidence'],
            'reliable': detection['reliable']
        })
    
    return results

# %%
class FastReviewAnalyzer:
    """Optimized analyzer for large datasets"""
    
    def __init__(self, use_parallel=True, n_workers=None):
        self.language_sentiment = {}
        self.detection_details = []
        self.use_parallel = use_parallel
        self.n_workers = n_workers or max(1, mp.cpu_count() - 1)
        self.processing_time = 0
    
    def analyze_reviews(self, reviews, show_progress=True):
        """
        Fast analysis with optional parallel processing
        
        Args:
            reviews: List of review dicts with 'text' and optional 'rating'
            show_progress: Show progress updates
        """
        start_time = time.time()
        total = len(reviews)
        
        print(f"Processing {total:,} reviews...")
        if self.use_parallel and total > 100:
            print(f"Using parallel processing with {self.n_workers} workers")
        print()
        
        # Process reviews
        if self.use_parallel and total > 100:
            # Parallel processing for large datasets
            all_results = self._process_parallel(reviews, show_progress)
        else:
            # Sequential processing for small datasets
            all_results = self._process_sequential(reviews, show_progress)
        
        # Aggregate results
        self._aggregate_results(all_results)
        
        self.processing_time = time.time() - start_time
        
        print(f"\n✓ Processed {total:,} reviews in {self.processing_time:.2f} seconds")
        print(f"  Speed: {total/self.processing_time:.0f} reviews/second")
        
        return self.language_sentiment, all_results
    
    def _process_sequential(self, reviews, show_progress):
        """Sequential processing (for small datasets)"""
        results = []
        total = len(reviews)
        
        for i, review in enumerate(reviews):
            text = review.get('text', '')
            rating = review.get('rating', 0)
            
            detection = detect_language_fast(text)
            
            result = {
                'text': text[:50] + '...' if len(text) > 50 else text,
                'full_text': text,
                'language': detection['language'],
                'code': detection['code'],
                'rating': rating,
                'confidence': detection['confidence'],
                'reliable': detection['reliable']
            }
            
            results.append(result)
            
            # Progress update
            if show_progress and (i + 1) % 1000 == 0:
                progress = (i + 1) / total * 100
                print(f"Progress: {i+1:,}/{total:,} ({progress:.1f}%)")
        
        return results
    
    def _process_parallel(self, reviews, show_progress):
        """Parallel processing (for large datasets)"""
        # Determine optimal batch size
        batch_size = max(100, len(reviews) // (self.n_workers * 4))
        batches = list(split_into_batches(reviews, batch_size))
        
        all_results = []
        processed = 0
        total = len(reviews)
        
        # Use ThreadPoolExecutor (faster for I/O bound tasks)
        with ThreadPoolExecutor(max_workers=self.n_workers) as executor:
            futures = [executor.submit(process_review_batch, batch) for batch in batches]
            
            for future in futures:
                batch_results = future.result()
                all_results.extend(batch_results)
                
                processed += len(batch_results)
                if show_progress and processed % 5000 < batch_size:
                    progress = processed / total * 100
                    print(f"Progress: {processed:,}/{total:,} ({progress:.1f}%)")
        
        return all_results
    
    def _aggregate_results(self, all_results):
        """Aggregate results into language categories"""
        self.detection_details = all_results
        
        for result in all_results:
            language = result['language']
            
            if language not in self.language_sentiment:
                self.language_sentiment[language] = {
                    'reviews': [],
                    'count': 0,
                    'total_rating': 0,
                    'avg_rating': 0,
                    'total_confidence': 0,
                    'avg_confidence': 0
                }
            
            self.language_sentiment[language]['reviews'].append(result)
            self.language_sentiment[language]['count'] += 1
            self.language_sentiment[language]['total_rating'] += result['rating']
            self.language_sentiment[language]['total_confidence'] += result['confidence']
        
        # Calculate averages
        for lang in self.language_sentiment:
            data = self.language_sentiment[lang]
            count = data['count']
            if count > 0:
                data['avg_rating'] = data['total_rating'] / count
                data['avg_confidence'] = data['total_confidence'] / count
    
    def print_summary(self, top_n=10):
        """Print quick summary"""
        total = sum(data['count'] for data in self.language_sentiment.values())
        
        print("\n" + "="*80)
        print("REVIEW ANALYSIS SUMMARY")
        print("="*80)
        print(f"Total reviews: {total:,}")
        print(f"Languages detected: {len(self.language_sentiment)}")
        print(f"Processing time: {self.processing_time:.2f} seconds")
        print(f"Speed: {total/self.processing_time:.0f} reviews/second")
        print("="*80 + "\n")
        
        # Sort by count
        sorted_langs = sorted(
            self.language_sentiment.items(),
            key=lambda x: x[1]['count'],
            reverse=True
        )
        
        print(f"Top {min(top_n, len(sorted_langs))} Languages:")
        print("-"*80)
        
        for i, (lang, data) in enumerate(sorted_langs[:top_n], 1):
            percentage = (data['count'] / total) * 100
            print(f"{i}. {lang}")
            print(f"   Reviews: {data['count']:,} ({percentage:.1f}%)")
            print(f"   Avg Rating: {data['avg_rating']:.2f}/5.0")
            print(f"   Avg Confidence: {data['avg_confidence']:.1f}%")
            print()
    
    def get_low_confidence_reviews(self, threshold=80, max_display=20):
        """Identify low confidence reviews (optimized)"""
        low_conf = [
            detail for detail in self.detection_details
            if detail['confidence'] < threshold
        ]
        
        print(f"\n⚠️  Reviews with confidence below {threshold}%: {len(low_conf):,}")
        
        if low_conf and len(low_conf) <= max_display:
            print("-"*80)
            for i, detail in enumerate(low_conf[:max_display], 1):
                print(f"{i}. {detail['text']}")
                print(f"   Detected: {detail['language']} ({detail['confidence']:.1f}%)")
                print()
        elif len(low_conf) > max_display:
            print(f"Showing first {max_display}:")
            print("-"*80)
            for i, detail in enumerate(low_conf[:max_display], 1):
                print(f"{i}. {detail['text']}")
                print(f"   Detected: {detail['language']} ({detail['confidence']:.1f}%)")
                print()
            print(f"... and {len(low_conf) - max_display:,} more")
        else:
            print(f"✓ All reviews detected with confidence above {threshold}%")
        
        return low_conf
    
    def export_to_dataframe(self):
        """Convert results to pandas DataFrame"""
        data = []
        for detail in self.detection_details:
            data.append({
                'review_text': detail['full_text'],
                'language': detail['language'],
                'language_code': detail['code'],
                'rating': detail['rating'],
                'confidence': detail['confidence'],
                'reliable': detail['reliable']
            })
        
        return pd.DataFrame(data)

print("✓ Fast Review Analyzer ready!")
# Out:
# ✓ Fast Review Analyzer ready!

# %%
analyzer = FastReviewAnalyzer(use_parallel=True)
product_reviews = [{'text': text} for text in df['review_body']]
sentiment, results = analyzer.analyze_reviews(product_reviews)
analyzer.print_summary()
analyzer.get_low_confidence_reviews(threshold=80)
# Out:
# Processing 1,200,000 reviews...
# Using parallel processing with 3 workers
#
# Progress: 100,000/1,200,000 (8.3%)
# Progress: 200,000/1,200,000 (16.7%)
# Progress: 300,000/1,200,000 (25.0%)
# Progress: 400,000/1,200,000 (33.3%)
# Progress: 500,000/1,200,000 (41.7%)
# Progress: 600,000/1,200,000 (50.0%)
# Progress: 700,000/1,200,000 (58.3%)
# Progress: 800,000/1,200,000 (66.7%)
# Progress: 900,000/1,200,000 (75.0%)
# Progress: 1,000,000/1,200,000 (83.3%)
# Progress: 1,100,000/1,200,000 (91.7%)
# Progress: 1,200,000/1,200,000 (100.0%)
#
# ✓ Processed 1,200,000 reviews in 11.93 seconds
#   Speed: 100624 reviews/second
#
# ================================================================================
# REVIEW ANALYSIS SUMMARY
# ================================================================================
# Total reviews: 1,200,000
# Languages detected: 52
# Processing time: 11.93 seconds
# Speed: 100624 reviews/second
# ================================================================================
#
# Top 10 Languages:
# --------------------------------------------------------------------------------
# 1. ENGLISH
#    Reviews: 201,861 (16.8%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 98.3%
#
# 2. Japanese
#    Reviews: 200,034 (16.7%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 98.1%
#
# 3. GERMAN
#    Reviews: 199,202 (16.6%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 98.6%
#
# 4. FRENCH
#    Reviews: 195,526 (16.3%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 98.4%
#
# 5. Chinese
#    Reviews: 194,742 (16.2%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 97.7%
#
# 6. SPANISH
#    Reviews: 193,180 (16.1%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 98.4%
#
# 7. Unknown
#    Reviews: 13,700 (1.1%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 0.0%
#
# 8. ChineseT
#    Reviews: 709 (0.1%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 91.5%
#
# 9. INDONESIAN
#    Reviews: 209 (0.0%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 96.4%
#
# 10. PORTUGUESE
#    Reviews: 175 (0.0%)
#    Avg Rating: 0.00/5.0
#    Avg Confidence: 96.8%
#
#
# ⚠️  Reviews with confidence below 80%: 16,602
# Showing first 20:
# --------------------------------------------------------------------------------
# 1. nach 2 monaten kaputt
#    Detected: Unknown (0.0%)
#
# 2. Funktioniert nicht mit Osmo pocket
#    Detected: Unknown (0.0%)
#
# 3. Windows 10 nach Clean Installation kein Lizenz! Su...
#    Detected: Unknown (0.0%)
#
# 4. The beans smelled and tasted sour and spoiled, eve...
#    Detected: ENGLISH (68.0%)
#
# 5. Nach nur 4 Monaten defekt.
#    Detected: Unknown (0.0%)
#
# 6. Es wurde nie geliefert!!
#    Detected: Unknown (0.0%)
#
# 7. 1.teil gut 2.teil gerede
#    Detected: Unknown (0.0%)
#
# 8. Nach 8 Monaten defekt.
#    Detected: Unknown (0.0%)
#
# 9. Schlecht ausgefallen!
#    Detected: Unknown (0.0%)
#
# 10. Kann man nicht fest spannen.
#    Detected: Unknown (0.0%)
#
# 11. Der Preis sagt alles.
#    Detected: Unknown (0.0%)
#
# 12. Bringt nix, sehr laut
#    Detected: Unknown (0.0%)
#
# 13. Klang schlecht Tragekomfort schlecht Sehr leise
#    Detected: Unknown (0.0%)
#
# 14. Total enttäuscht. Nicht praktisch
#    Detected: Unknown (0.0%)
#
# 15. leider nach 3 Monaten defekt!
#    Detected: Unknown (0.0%)
#
# 16. Habe 3 x Schwarzkopf Professional BONACURE Hyaluro...
#    Detected: GERMAN (70.0%)
#
# 17. Schon nach 14 Monaten defekt
#    Detected: Unknown (0.0%)
#
# 18. Habe ich nie bekommen !
#    Detected: Unknown (0.0%)
#
# 19. Wartet zu lange schon auf die Ware. Es ist nicht m...
#    Detected: ENGLISH (62.0%)
#
# 20. Nach paar Monaten kaputt
#    Detected: Unknown (0.0%)
#
# ... and 16,582 more
# [{'text': 'nach 2 monaten kaputt',
#   'full_text': 'nach 2 monaten kaputt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Funktioniert nicht mit Osmo pocket',
#   'full_text': 'Funktioniert nicht mit Osmo pocket',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Windows 10 nach Clean Installation kein Lizenz! Su...',
#   'full_text': 'Windows 10 nach Clean Installation kein Lizenz! Support für Treiber SEHR SCHLECHT!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'The beans smelled and tasted sour and spoiled, eve...',
#   'full_text': 'The beans smelled and tasted sour and spoiled, even though the "use-by" date was in the future. Do not waste your money on them! Die Bohnen haben sauer und vergammelt geschmeckt und gerochen, obwohl der MHD in Ordnung war. Ich kann sie nicht empfehlen!',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 68,
#   'reliable': True},
#  {'text': 'Nach nur 4 Monaten defekt.',
#   'full_text': 'Nach nur 4 Monaten defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Es wurde nie geliefert!!',
#   'full_text': 'Es wurde nie geliefert!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': '1.teil gut 2.teil gerede',
#   'full_text': '1.teil gut 2.teil gerede',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 8 Monaten defekt.',
#   'full_text': 'Nach 8 Monaten defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Schlecht ausgefallen!',
#   'full_text': 'Schlecht ausgefallen!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Kann man nicht fest spannen.',
#   'full_text': 'Kann man nicht fest spannen.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der Preis sagt alles.',
#   'full_text': 'Der Preis sagt alles.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Bringt nix, sehr laut',
#   'full_text': 'Bringt nix, sehr laut',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Klang schlecht Tragekomfort schlecht Sehr leise',
#   'full_text': 'Klang schlecht Tragekomfort schlecht Sehr leise',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Total enttäuscht. Nicht praktisch',
#   'full_text': 'Total enttäuscht. Nicht praktisch',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'leider nach 3 Monaten defekt!',
#   'full_text': 'leider nach 3 Monaten defekt!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Habe 3 x Schwarzkopf Professional BONACURE Hyaluro...',
#   'full_text': 'Habe 3 x Schwarzkopf Professional BONACURE Hyaluronic Moisture Kick Spray Conditioner, 200 ml bei Friseurbedarf Peters bestellt, bekommen habe ich Schwarzkopf BC Moisture Kick Conditioner 200 ml 3er-Pack, ergibt für mich einen Preisunterschied von ca. 10 €. Wie kann so was passieren, 3 einzelne Flaschen werden bestellt und es wird zu einem ganz anderen Produkt im 3er-Pack gegriffen?',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 70,
#   'reliable': True},
#  {'text': 'Schon nach 14 Monaten defekt',
#   'full_text': 'Schon nach 14 Monaten defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Habe ich nie bekommen !',
#   'full_text': 'Habe ich nie bekommen !',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Wartet zu lange schon auf die Ware. Es ist nicht m...',
#   'full_text': 'Wartet zu lange schon auf die Ware. Es ist nicht mehr angekommen. Verkauefer antwortet auch nicht auf meine mails. Sehr sehr schlecht!!! soll man nicht hier weiter verkaufen. English: Never communicate with me...waiting so long for the package,didnt deliverd!!!! Bad bad bad!!! not good!!!!',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 62,
#   'reliable': True},
#  {'text': 'Nach paar Monaten kaputt',
#   'full_text': 'Nach paar Monaten kaputt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Viel zu klein schade',
#   'full_text': 'Viel zu klein schade',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 2 monaten defekt',
#   'full_text': 'Nach 2 monaten defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Controller geht nicht',
#   'full_text': 'Controller geht nicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Einfach nur langweilig.',
#   'full_text': 'Einfach nur langweilig.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Artikel km nicht an. 🤷\u200d♀️',
#   'full_text': 'Artikel km nicht an. 🤷\u200d♀️',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Das war ein Reinfall.',
#   'full_text': 'Das war ein Reinfall.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'KEIN Original ZIPPO! Funktioniert nicht richtig!',
#   'full_text': 'KEIN Original ZIPPO! Funktioniert nicht richtig!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'They lost my package have failed at responding to ...',
#   'full_text': 'They lost my package have failed at responding to my messages days later. Very disappointing. Just took my money. Sie haben mein Paket verloren und konnten einige Tage später nicht auf meine Nachrichten antworten. Sehr enttäuschend. Habe gerade mein Geld genommen',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 68,
#   'reliable': True},
#  {'text': 'Hat bei iphone 6 nicht funktioniert',
#   'full_text': 'Hat bei iphone 6 nicht funktioniert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Billigschrott, nach kürzester Zeit defekt!',
#   'full_text': 'Billigschrott, nach kürzester Zeit defekt!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 5 Monaten schon kaputt.',
#   'full_text': 'Nach 5 Monaten schon kaputt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': '....ich fand den Film super langweilig',
#   'full_text': '....ich fand den Film super langweilig',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach drei Monaten defekt.',
#   'full_text': 'Nach drei Monaten defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach nur 7 Monaten kaputt!!',
#   'full_text': 'Nach nur 7 Monaten kaputt!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der Kartenleser funktioniert nicht, doofe Investit...',
#   'full_text': 'Der Kartenleser funktioniert nicht, doofe Investition.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Wenn man Andoer LED Mini Interlock Videoleuchte, 8...',
#   'full_text': 'Wenn man Andoer LED Mini Interlock Videoleuchte, 81 LED Video Light herstellt dann muss der Artikel auch funktionieren. Leider war dieses Andoer LED Mini Interlock Videoleuchte, 81 LED Video Light defekt was mir noch nie passiert ist und das seid 2011. Sorry wer Schrott produziert braucht sich nicht wundern wenn der Artikel zurückgesandt wird. Ich werde bei diesem Verkäufer nichts mehr kaufen',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 79,
#   'reliable': True},
#  {'text': 'risse nach 3 monaten. undicht nach 8 monaten.',
#   'full_text': 'risse nach 3 monaten. undicht nach 8 monaten.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Er kam leider garnicht an',
#   'full_text': 'Er kam leider garnicht an',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Klebt nur ganz schlecht. Bin mega enttäuscht.',
#   'full_text': 'Klebt nur ganz schlecht. Bin mega enttäuscht.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 7 Monaten defekt!',
#   'full_text': 'Nach 7 Monaten defekt!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Falsches Produkt geliefert',
#   'full_text': 'Falsches Produkt geliefert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Miracast auf einen Fire TV 4k Stick vom einem Wind...',
#   'full_text': 'Miracast auf einen Fire TV 4k Stick vom einem Windows 10 Laptop funktioniert nicht. Der Laptop erkennt die App partout nicht unter den gesuchten Geräten.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 50,
#   'reliable': False},
#  {'text': 'China-Produkt aus Litauen versandt, Sauerei',
#   'full_text': 'China-Produkt aus Litauen versandt, Sauerei',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Kaputt nach 2mal tragen',
#   'full_text': 'Kaputt nach 2mal tragen',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'War nach 2 Wochen defekt',
#   'full_text': 'War nach 2 Wochen defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 9 Monaten Defekt',
#   'full_text': 'Nach 9 Monaten Defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider keine Wirkung',
#   'full_text': 'Leider keine Wirkung',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Funktioniert nicht bezw. Klingelt nicht',
#   'full_text': 'Funktioniert nicht bezw. Klingelt nicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'SSD Festplatte war nicht verschraubt, die Schraube...',
#   'full_text': 'SSD Festplatte war nicht verschraubt, die Schraube fehlt. Der untere Deckel ist beschädigt und 2 Schnapper sind gebrochen. Die Bedienungsanleitung fehlt. Windows 10 DVD fehlt , Windows 10 Zertifikat fehlt. DVD Treiber fehlt.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 70,
#   'reliable': True},
#  {'text': 'Leider sehr sehr schlecht..👎👎👎👎',
#   'full_text': 'Leider sehr sehr schlecht..👎👎👎👎',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ware kam nicht an. Betrugsfall',
#   'full_text': 'Ware kam nicht an. Betrugsfall',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Das war ein Reinfall',
#   'full_text': 'Das war ein Reinfall',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'bereits wieder defekt',
#   'full_text': 'bereits wieder defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ich hatte gleich zwei bestellt. Beide zeigen unter...',
#   'full_text': 'Ich hatte gleich zwei bestellt. Beide zeigen unterschiedliche Temperaturen an. Differenz 4 Grad. Differenz zur realen Temperatur größer als 8 Grad. Made in Germany? Denke eher made in China.',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 57,
#   'reliable': True},
#  {'text': 'The filament clogged the nozzle of my Anycubic i3 ...',
#   'full_text': "The filament clogged the nozzle of my Anycubic i3 mega now 6 times.... As you can see I do not seem to learn very fast ;-) Well I just thought when I heat the nozzle up a bit more it won't close up the nozzle. Well now I won't give it another try... Das Filament hat die Spitze meines Anycubic i3 mega 6mal verklebt. Wie man sehen kann scheine ich nicht so schnell zu lernen... Naja ich dachte wenn ich z.B. die Temperatur erhöhe das es besser fließt und dann nicht mehr verklebt aber naja, nach 6mal habe ich jetzt keine Lust mehr...",
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 58,
#   'reliable': True},
#  {'text': 'Der Artikel wurde mir in einem gebrauchten Zustand...',
#   'full_text': 'Der Artikel wurde mir in einem gebrauchten Zustand gesendet. Es gab leider schon Haare an der Maschine. Nicht nett vom Verkäufer. The machine was sent to me already used. There was hear on it and I first opened the box. Not a nice at all.',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 59,
#   'reliable': True},
#  {'text': 'Langatmig und langweilig.',
#   'full_text': 'Langatmig und langweilig.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'nach 20 Minuten sinnlosem gelaber in den müll befö...',
#   'full_text': 'nach 20 Minuten sinnlosem gelaber in den müll befördert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider schon nach 2 Monaten kaputt',
#   'full_text': 'Leider schon nach 2 Monaten kaputt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 4 Monaten komplett kaputt',
#   'full_text': 'Nach 4 Monaten komplett kaputt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Wurde defekt versendet',
#   'full_text': 'Wurde defekt versendet',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'falscher Artikel 2x geliefert',
#   'full_text': 'falscher Artikel 2x geliefert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der Treiber für Windows 7 funktioniert nicht. Scho...',
#   'full_text': 'Der Treiber für Windows 7 funktioniert nicht. Schon bei der Installation wird das Gerät im Gerätemanger mit einem Ausrufezeichen angezeigt. Mit einer Deinstallation des Gerätes, Deinstallation der Software und Neuinstallation der Software läuft das ganze dann... Aber nur bis zum nächsten Neustart oder falls der USB-Stecker gezogen wird. Dann ist das Gerät wieder deinstalliert. Hier ein Auszug aus der Support-Mail: The Win7 MIDI is problematic because the MIDI was rather new invention when Win7 was released and Microsoft has since made many improvements to newer versions and the Win7 MIDI is not perfect. We are making changes to our software to stabilise the MIDI connection system further, however this will take time. Schlecht. Dann werde ich das Loupedeck wieder zurückgeben.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 59,
#   'reliable': True},
#  {'text': 'Adapter funktioniert nicht mit Macbook Pro 2015 re...',
#   'full_text': 'Adapter funktioniert nicht mit Macbook Pro 2015 retina. Mit einem Windows Notebook kam ein Bild (ob es eine lange Kabellänge überbrücken kann, habe ich nicht getestet. Bei einem MBP sieht man kurz ein flimmerndes Bild, dann wird es schwarz. Getestet mit einem 1,5 m HDMI Kabel, welches HDCP 2.0 tauglich war. Schade, aber die Adapter gehen wieder zurück.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 75,
#   'reliable': True},
#  {'text': 'schlehte artikel fast alle klein luftballons mit l...',
#   'full_text': 'schlehte artikel fast alle klein luftballons mit loch.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Hat es leider garnicht geklappt 🤔',
#   'full_text': 'Hat es leider garnicht geklappt 🤔',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'NACH PAAR MONATEN DEFEKT',
#   'full_text': 'NACH PAAR MONATEN DEFEKT',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Schrott. Der Plastik Aufhänger bricht nach einmali...',
#   'full_text': 'Schrott. Der Plastik Aufhänger bricht nach einmaligem Gebrauch ab.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Lichterkette hat leider nie funktioniert....',
#   'full_text': 'Lichterkette hat leider nie funktioniert....',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Service, was wie ein Service???',
#   'full_text': 'Service, was wie ein Service???',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Bin entäuscht, sehr klein.',
#   'full_text': 'Bin entäuscht, sehr klein.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'nach 2 Monaten kaputt!!!',
#   'full_text': 'nach 2 Monaten kaputt!!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach ca. 6 Wochen bei normalem Gebrauch gebrochen....',
#   'full_text': 'Nach ca. 6 Wochen bei normalem Gebrauch gebrochen. (Kein Sturz!)',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 1 Woche kaputt..',
#   'full_text': 'Nach 1 Woche kaputt..',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Kamm mit defektem Stiel....!!!',
#   'full_text': 'Kamm mit defektem Stiel....!!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Item never came and no response from seller despit...',
#   'full_text': 'Item never came and no response from seller despite repeated tries for a resolution Artikel kam nie und keine Antwort vom Verkäufer trotz wiederholter Versuche für eine Lösung',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 51,
#   'reliable': True},
#  {'text': 'Produkt kam nicht an!',
#   'full_text': 'Produkt kam nicht an!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ich hätte gern 0 Punkte gegeben. Es war so billig ...',
#   'full_text': 'Ich hätte gern 0 Punkte gegeben. Es war so billig / schlecht verpackt, dass es sich verformte. Es ist keinen Cent wert, man kann es nur wegwerfen. !!! It was so poor covered for the shipping, that it is not usable anymore. !!!! It is rubbish.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 70,
#   'reliable': True},
#  {'text': 'Nach 4 Monaten undicht',
#   'full_text': 'Nach 4 Monaten undicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Sehr laut... riecht extrem nach Plastik wenn man e...',
#   'full_text': 'Sehr laut... riecht extrem nach Plastik wenn man es anmacht.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Einfach nur langweilig.',
#   'full_text': 'Einfach nur langweilig.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Wahrscheinlich eine Fälschung!!! Bilder passen nic...',
#   'full_text': 'Wahrscheinlich eine Fälschung!!! Bilder passen nicht zu den Nummern..... das ist Mist und echt mies! Geht gar nicht so was. Aber dass die Bilder NICHT kompatibel sind zum deutschen Album sollte deutlicher hervorgehoben werden, zum Beispiel in der Headline YOU BUY FROM A GERMAN SITE EXPECT CLEAR INFORMATION NOT TO BE SCAMMED BY SELLING A NON COMPATIBLE VERSION WORSE EXPERIENCE ON ANY AMAZON AROUND THE WORLD',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 50,
#   'reliable': True},
#  {'text': 'Grausiger Gestank nach giftigen Chemikalien',
#   'full_text': 'Grausiger Gestank nach giftigen Chemikalien',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach nicht mal 2 Monaten Defekt',
#   'full_text': 'Nach nicht mal 2 Monaten Defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Es kam ein China Fake und kein Original hasbro BEY...',
#   'full_text': 'Es kam ein China Fake und kein Original hasbro BEYBLADE.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Fruit of the loom war in den 80er bis in die 90er ...',
#   'full_text': 'Fruit of the loom war in den 80er bis in die 90er eine gute Marke mit super Qualität. Heute ist es nur noch Müll. Nutze die Hosen schon als Putzlappen da mehr nicht geht.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 56,
#   'reliable': True},
#  {'text': 'Nach 3 Monaten LEDs defekt',
#   'full_text': 'Nach 3 Monaten LEDs defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Touchscreen funktioniert nicht gut',
#   'full_text': 'Touchscreen funktioniert nicht gut',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider nicht kostenlos',
#   'full_text': 'Leider nicht kostenlos',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Einfach langweilig, gute Idee - schlechte Umsetzun...',
#   'full_text': 'Einfach langweilig, gute Idee - schlechte Umsetzung.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nicht besonders gut Batterien sind Knopfbatterien ...',
#   'full_text': 'Nicht besonders gut Batterien sind Knopfbatterien und halten nur eine Nacht! Zudem ist es auch sehr hart und eignet sich nicht für Kinder was ihre Nachtlichter gerne mit ins Bett nehmen!! Not very good Batteries are button batteries and last only one night! In addition, it is also very hard and is not suitable for children what their night lights like to bed !!',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 51,
#   'reliable': True},
#  {'text': 'Nach 3 Monaten defekt.....',
#   'full_text': 'Nach 3 Monaten defekt.....',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Akkus nach 2 Monaten dauer leer..',
#   'full_text': 'Akkus nach 2 Monaten dauer leer..',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Stinken extrem nach Benzin',
#   'full_text': 'Stinken extrem nach Benzin',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'war defekt (stift verbogen) => hab es entsorgt ☹️',
#   'full_text': 'war defekt (stift verbogen) => hab es entsorgt ☹️',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Funkcioniert nicht !!!',
#   'full_text': 'Funkcioniert nicht !!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'The top of the page cannot slide open - old produc...',
#   'full_text': 'The top of the page cannot slide open - old product? Very disappointed because I wanted to be able to open the roof of the cage! Das Dach des Käfigs lässt sich nicht öffnen - ein überholtes Produkt? Sehr enttäuscht - ich wollte das Dach des Käfigs öffnen können!',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 67,
#   'reliable': True},
#  {'text': 'This product is very bad ,ich habe fur meinr tauch...',
#   'full_text': 'This product is very bad ,ich habe fur meinr tauchter gekauft .sie hat nur eine stunde benutz und kaput schnell .die firma ist sehr schlecht',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 57,
#   'reliable': True},
#  {'text': 'Der Home Button funktioniert nicht durch die Folie...',
#   'full_text': 'Der Home Button funktioniert nicht durch die Folie! ☹️',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Fake wurde nie geliefert',
#   'full_text': 'Fake wurde nie geliefert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'funkzioniert nicht korrekt',
#   'full_text': 'funkzioniert nicht korrekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Das Produkt wirbt damit vom. TÜV geprüft zu sein, ...',
#   'full_text': 'Das Produkt wirbt damit vom. TÜV geprüft zu sein, steht dort aber auf der schwarzen Liste. Stinkt nach Chemie! https://www.tuv.com/germany/de/search.html#Songmics',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 58,
#   'reliable': True},
#  {'text': 'Alles sehr schlecht !',
#   'full_text': 'Alles sehr schlecht !',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach einem halben Jahr ist die Verbindung mit den ...',
#   'full_text': 'Nach einem halben Jahr ist die Verbindung mit den schnelleren 5-Ghz Netzen nicht mehr möglich, sodass der Stick nur noch stark eingeschränkt nutzbar ist. After a half year of regular use the stick is not connecting to my 5GHz wifi anymore.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 71,
#   'reliable': True},
#  {'text': 'Nach 2 Monaten kaputt',
#   'full_text': 'Nach 2 Monaten kaputt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Extrem schlechtes Zündverhalten',
#   'full_text': 'Extrem schlechtes Zündverhalten',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Knackt und quietscht!',
#   'full_text': 'Knackt und quietscht!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Extra als alternative Dock für Nintendo Switch gek...',
#   'full_text': 'Extra als alternative Dock für Nintendo Switch gekauft. Die Nintendo Switch bekommt Strom, aber das Signal kommt nicht am Fernseher an. Darum ist es nicht als Dock zu gebrauchen. Schade.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 50,
#   'reliable': False},
#  {'text': 'Richtig Richtig schlecht, wird Prime angeboten und...',
#   'full_text': 'Richtig Richtig schlecht, wird Prime angeboten und kassieren dann 4,50€ Versandkosten.bei einem Artikel für 4,20€ macht das wenig Sinn! Rücksendung beantragt und siehe da auch hier soll ich selbst frankieren sprich nochmal Versandkosten....heimwerkertools high five with a Chair in your face.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 68,
#   'reliable': True},
#  {'text': 'Es war alles unkompliziert alles ok',
#   'full_text': 'Es war alles unkompliziert alles ok',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'retuniert while die nicht funktioniert',
#   'full_text': 'retuniert while die nicht funktioniert',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Funktioniert nicht mit Alexa !😡',
#   'full_text': 'Funktioniert nicht mit Alexa !😡',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der Film ist total langweilig',
#   'full_text': 'Der Film ist total langweilig',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Die Stiefel waren 3 Nummern zu klein.',
#   'full_text': 'Die Stiefel waren 3 Nummern zu klein.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der schlechteste Film mit Simon Pegg',
#   'full_text': 'Der schlechteste Film mit Simon Pegg',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Die Stimme bricht...',
#   'full_text': 'Die Stimme bricht...',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Entweder ist mein Gerät defekt, oder es ist einfac...',
#   'full_text': "Entweder ist mein Gerät defekt, oder es ist einfach nicht durchdacht. Auf Bewegung reagiert es gar nicht. Nur auf dunkel (an), hell (aus) Wechsel des Lichts im Raum. 🤔 ??? Das Badezimmer ist dunkel, man tanzt quasi vor dem Sensor herum, aber er schaltet die LED nicht an. Schaltet man die Badezimmerbeleuchtung an und wieder aus, geht die LED am Gerät an und nach ein paar Sekunden wieder aus. Bewegt man sich nochmal im Dunkel, bleibt die LED weiterhin aus. 😳 Irgendwie unnütz. Either my device is faulty, or it's just not well thought out. It doesn't respond to movement at all. Only if the room ceiling light switches dark (on), light (off) 🤔 ??? The bathroom is dark, you dance around in front of the sensor, but it doesn't turn the LED on. If you turn the bathroom ceiling lighting on and off again, the LED on the unit turns on and off again after a few seconds. If you move in the dark again, the LED stays off. 😳 Kind of useless.",
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 50,
#   'reliable': True},
#  {'text': 'absoluter Mist funktioniert nicht',
#   'full_text': 'absoluter Mist funktioniert nicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Absoluter Schrott.Gewinde schief,nicht zu gebrauch...',
#   'full_text': 'Absoluter Schrott.Gewinde schief,nicht zu gebrauchen, Finger weg',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach gerade mal 11 Monaten kaputt.',
#   'full_text': 'Nach gerade mal 11 Monaten kaputt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Hat nicht in der Maschine gepasst',
#   'full_text': 'Hat nicht in der Maschine gepasst',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Beide Lager nach 15 km defekt.',
#   'full_text': 'Beide Lager nach 15 km defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 1800 km defekt....',
#   'full_text': 'Nach 1800 km defekt....',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der letzte Dreck, nach 20 Blatt war Feierabend',
#   'full_text': 'Der letzte Dreck, nach 20 Blatt war Feierabend',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'einfach schlecht !!!',
#   'full_text': 'einfach schlecht !!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Kitschige Farbe. Bin enttäuscht',
#   'full_text': 'Kitschige Farbe. Bin enttäuscht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'War leider nicht dicht',
#   'full_text': 'War leider nicht dicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Brauch man nicht, da effektlos',
#   'full_text': 'Brauch man nicht, da effektlos',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Langatmig mit nervigen Dialogen',
#   'full_text': 'Langatmig mit nervigen Dialogen',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Waren über all Flecken dran',
#   'full_text': 'Waren über all Flecken dran',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Viele waren vertrocknen',
#   'full_text': 'Viele waren vertrocknen',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Tarantino Abklatsch mit alternden Dolph Lundgren',
#   'full_text': 'Tarantino Abklatsch mit alternden Dolph Lundgren',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Tut weh in den Ohren.',
#   'full_text': 'Tut weh in den Ohren.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'festplatte zu langsam',
#   'full_text': 'festplatte zu langsam',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Der Film ist langweilig 😑',
#   'full_text': 'Der Film ist langweilig 😑',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'nicht praktische Produkt finde ich.',
#   'full_text': 'nicht praktische Produkt finde ich.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Oberplatte ist schlecht verleimt.',
#   'full_text': 'Oberplatte ist schlecht verleimt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Problem mit aku ghet nur 1 tage...',
#   'full_text': 'Problem mit aku ghet nur 1 tage...',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Kabel nach 2 Monaten defekt.',
#   'full_text': 'Kabel nach 2 Monaten defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider ein Platten nach 2 Tagen.',
#   'full_text': 'Leider ein Platten nach 2 Tagen.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Was ein Kack. Rezension Ende.',
#   'full_text': 'Was ein Kack. Rezension Ende.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'war nach 2 Monaten defekt , schaltete nach 3 Minut...',
#   'full_text': 'war nach 2 Monaten defekt , schaltete nach 3 Minuten stumm',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'schlecht zu montieren',
#   'full_text': 'schlecht zu montieren',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 4 Monaten schon defekt.',
#   'full_text': 'Nach 4 Monaten schon defekt.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider die Jacke nicht dicht',
#   'full_text': 'Leider die Jacke nicht dicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider war die Klinge stump.',
#   'full_text': 'Leider war die Klinge stump.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider nach ca. 15 Monaten defekt',
#   'full_text': 'Leider nach ca. 15 Monaten defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Wurde explizit als Schutz für Funkschlüssel "Key-l...',
#   'full_text': 'Wurde explizit als Schutz für Funkschlüssel "Key-less" beworben. Getestet mit einem VW - blockt die Signale nicht. Das Auto lässt sich öffnen mit dem Schlüssel in der Mappe. Als Schlüsselmappe die auch einige Karten und Münzen aufnimmt ok - als Schutz gegen ungewolltes auslesen / verlängern des Signales mit dem getesteten VW Schlüssel nutzlos. English version Was sold as a protection for "key-less" car keys. Bought it to protect against simple "replay" attacks to open and start cars with "key less" system. Tested with a European VW there is no difference if the key is inside or outside.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 56,
#   'reliable': True},
#  {'text': 'gr.xxl ist maximal 36. Innen Fleece',
#   'full_text': 'gr.xxl ist maximal 36. Innen Fleece',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': '50/50 dass er klingelt',
#   'full_text': '50/50 dass er klingelt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach kurze zeit war schloß kaput!',
#   'full_text': 'Nach kurze zeit war schloß kaput!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ist der langweilig !',
#   'full_text': 'Ist der langweilig !',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'ACHTUNG, passen NICHT in den Angelcare Dress Up !!...',
#   'full_text': 'ACHTUNG, passen NICHT in den Angelcare Dress Up !!!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'After 2 weeks I have some problems: 1. Material of...',
#   'full_text': "After 2 weeks I have some problems: 1. Material of the strap is quite bad and hurts wrist. 2. It's not accurate at all. In the beginning I thought it's accurate but comparing to my phone and other accessories it's not. 3. Display is quite bad to look and it started flickering after some use. Please don't waste your time on this. Ich bin glücklich mit seiner Leistung für die letzten 3 Tage und Herr sind meine Gedanken, 1. Der Bildschirm ist für den Außenbereich ausreichend hell, nicht für die beste Bildqualität, aber er funktioniert. 2. Verbindet sich gut mit dem Telefon und hat eine eigene App. 3. Manchmal werden Schritte, die mit anderen Apps in meinem Telefon verglichen werden, nicht richtig gezählt. Ich bin bis jetzt mit dieser Fitnessband zufrieden.",
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 57,
#   'reliable': True},
#  {'text': 'Stumpf wie Kinderspielzeug!!!',
#   'full_text': 'Stumpf wie Kinderspielzeug!!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider nicht ganz passend.',
#   'full_text': 'Leider nicht ganz passend.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Hält was es verspricht',
#   'full_text': 'Hält was es verspricht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider nach 3 Tagen defekt',
#   'full_text': 'Leider nach 3 Tagen defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'einfach nur langweilig',
#   'full_text': 'einfach nur langweilig',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Nach 3 Monaten Motorschaden. Schade.',
#   'full_text': 'Nach 3 Monaten Motorschaden. Schade.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Spindel defekt siehe Bilder',
#   'full_text': 'Spindel defekt siehe Bilder',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': '.... blöd einfach blöd',
#   'full_text': '.... blöd einfach blöd',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Sieht zwar gut aus, ist aber schlecht verarbeitet....',
#   'full_text': 'Sieht zwar gut aus, ist aber schlecht verarbeitet. Ist einfach beim Tragen vom Handgelenk gefallen, weil sich der Stift vom Armband zur Uhr aufgelöst hat. Looks good but the quality is poor. Just dropped from my wrist as the connection from watch to bracelet just dissolved',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 67,
#   'reliable': True},
#  {'text': 'entsprach den Erwartungen',
#   'full_text': 'entsprach den Erwartungen',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Na ja, eindeutige Fake-Bewertungen hier.... why sh...',
#   'full_text': 'Na ja, eindeutige Fake-Bewertungen hier.... why should you write the subject in English, if the rest of your text follows in German? Die Tasse selbst kann man zur Aufbewahrung der Menstasse nutzen, jedoch nicht zum Sterilisieren in der Mikrowelle. Dafür reicht theoretisch auch jedes andere Gefäß.',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 54,
#   'reliable': True},
#  {'text': 'Really bad on hard wood floors. Pulls up the lacqu...',
#   'full_text': "Really bad on hard wood floors. Pulls up the lacquer on the wood Don't risk it. / Wirklich schlecht auf harten Holzböden. Zieht den Lack auf das Holz. Riskieren Sie es nicht.",
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 52,
#   'reliable': True},
#  {'text': 'Plastik billige Verarbeitung',
#   'full_text': 'Plastik billige Verarbeitung',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Stinkt anfangs arg nach strauss',
#   'full_text': 'Stinkt anfangs arg nach strauss',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Höchstens 2x tragbar',
#   'full_text': 'Höchstens 2x tragbar',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Leider nicht Wasser dicht',
#   'full_text': 'Leider nicht Wasser dicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Top serie für Kinder',
#   'full_text': 'Top serie für Kinder',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Rutscht , blendet, gefällt mir nicht',
#   'full_text': 'Rutscht , blendet, gefällt mir nicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Artikel war schnell defekt',
#   'full_text': 'Artikel war schnell defekt',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Bringt leider nichts',
#   'full_text': 'Bringt leider nichts',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'eins war leider kapput',
#   'full_text': 'eins war leider kapput',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Hat nicht ganz gepasst..',
#   'full_text': 'Hat nicht ganz gepasst..',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'material nicht gut ,',
#   'full_text': 'material nicht gut ,',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'You get what you pay. Preiswerte Kopfhörer. Passiv...',
#   'full_text': 'You get what you pay. Preiswerte Kopfhörer. Passives noise cancelling. Plastikadapter bleiben leider häufig beim Entnehmen im Ohr hängen. Die Klangqualität ist ok. Basslastig. Update Nicht mehr brauchbar. Ohrstöpsel lösen sich und bleiben im Ohr stecken.',
#   'language': 'GERMAN',
#   'code': 'de',
#   'rating': 0,
#   'confidence': 63,
#   'reliable': False},
#  {'text': 'Kein Vollbild schade.',
#   'full_text': 'Kein Vollbild schade.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Sender bleiben nicht',
#   'full_text': 'Sender bleiben nicht',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Artikel noch nicht geliefert worden',
#   'full_text': 'Artikel noch nicht geliefert worden',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'dient als deko und raumduft...',
#   'full_text': 'dient als deko und raumduft...',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Bitte ,Schliessen Sie dieses Bild von Sodium Chlor...',
# ...
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Las ceras se rompen con mirarlas',
#   'full_text': 'Las ceras se rompen con mirarlas',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No es lo que esperaba',
#   'full_text': 'No es lo que esperaba',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Estropeado no funciona no carga y se ajusta miy ma...',
#   'full_text': 'Estropeado no funciona no carga y se ajusta miy mal al iphone 5 desilusionado no se como devolverlo ya ya',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No resiste lo que marca',
#   'full_text': 'No resiste lo que marca',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'se desgasta rapido, se quita el color hasta sin la...',
#   'full_text': 'se desgasta rapido, se quita el color hasta sin lavarlo , solo con usarlo',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Da problemas en los controles',
#   'full_text': 'Da problemas en los controles',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Horrible tejido y horrible vestido,es más bonito e...',
#   'full_text': 'Horrible tejido y horrible vestido,es más bonito en la foto.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Mal, muy simple, mal',
#   'full_text': 'Mal, muy simple, mal',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'no funciona , nada de nada',
#   'full_text': 'no funciona , nada de nada',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'A veces carga, a veces no carga y otras veces DESC...',
#   'full_text': 'A veces carga, a veces no carga y otras veces DESCARGA. Es muy desagradable despertarte y que el iPhone o el watch estén completamente descargados.',
#   'language': 'ENGLISH',
#   'code': 'en',
#   'rating': 0,
#   'confidence': 56,
#   'reliable': True},
#  {'text': 'Funcionó durante una semana.',
#   'full_text': 'Funcionó durante una semana.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No funciona por usb c.',
#   'full_text': 'No funciona por usb c.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Desastre. No incluye ningún cable. Es tan útil com...',
#   'full_text': 'Desastre. No incluye ningún cable. Es tan útil como un cenicero en una moto.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Pague y no me llego la bolsa.',
#   'full_text': 'Pague y no me llego la bolsa.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Para nada es una varita, es un trozo de plástico l...',
#   'full_text': 'Para nada es una varita, es un trozo de plástico largo y gordo',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'son pegatinas de plástico con pega',
#   'full_text': 'son pegatinas de plástico con pega',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Parecia genial, pero ni la bateria da potencia , n...',
#   'full_text': 'Parecia genial, pero ni la bateria da potencia , ni dura mas de una semana',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Han venido pegadas entre sí, son como de gente ma',
#   'full_text': 'Han venido pegadas entre sí, son como de gente ma',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Muy malo. Se resquebraja',
#   'full_text': 'Muy malo. Se resquebraja',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me han llegado con abolladuras la tapa superior.',
#   'full_text': 'Me han llegado con abolladuras la tapa superior.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No es una carcasa inteligente y se rompe en una se...',
#   'full_text': 'No es una carcasa inteligente y se rompe en una semana',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Por favor, no la compréis, es exageradamente mala....',
#   'full_text': 'Por favor, no la compréis, es exageradamente mala. Tras dos días de uso ya se me ha partido por el orificio de la entrada de auriculares. // Don’t buy this!! Absolutely poor quality!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'a la primera botella con resistencia se dobló el e...',
#   'full_text': 'a la primera botella con resistencia se dobló el espiral',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Son para persona bajita. Mido 165 cm y me van cort...',
#   'full_text': 'Son para persona bajita. Mido 165 cm y me van cortas',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Se rompe a los dos meses',
#   'full_text': 'Se rompe a los dos meses',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Que no cumple con lo anunciado, es una laca y no u...',
#   'full_text': 'Que no cumple con lo anunciado, es una laca y no un color blanco.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'El bote o tarro de cristal nos llego roto',
#   'full_text': 'El bote o tarro de cristal nos llego roto',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me han devuelto el importe completo,tras enviar ar...',
#   'full_text': 'Me han devuelto el importe completo,tras enviar articulo',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Un timo!!! Sin instrucciones solo en inglés y chin...',
#   'full_text': 'Un timo!!! Sin instrucciones solo en inglés y chino!! Imposible de instalar!!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me an llegado sin enchufe que mal',
#   'full_text': 'Me an llegado sin enchufe que mal',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Es para bicicletas de barbie. No cabe una rueda no...',
#   'full_text': 'Es para bicicletas de barbie. No cabe una rueda normal de mtb...',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Roto en el primer intento de uso. Una baratija.',
#   'full_text': 'Roto en el primer intento de uso. Una baratija.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Se rompió a la semana',
#   'full_text': 'Se rompió a la semana',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No funciona, sigue habiendo cucarachas',
#   'full_text': 'No funciona, sigue habiendo cucarachas',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'muy mal servicio del proveedor',
#   'full_text': 'muy mal servicio del proveedor',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Esta pulsera no encaja con el dispositivo, sobresa...',
#   'full_text': 'Esta pulsera no encaja con el dispositivo, sobresale y no se ajusta adecuadamente al marco. La correa al ser metálica no es flexible y es complicado sacar el dispositivo de la pulsera.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No funciona la grabacion por voz',
#   'full_text': 'No funciona la grabacion por voz',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Sin resultado en lo absoluto',
#   'full_text': 'Sin resultado en lo absoluto',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'no es lo que me esperaba',
#   'full_text': 'no es lo que me esperaba',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ha llegado roto. La rosca de la pinza',
#   'full_text': 'Ha llegado roto. La rosca de la pinza',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me equivoqué pensé que era libro físico',
#   'full_text': 'Me equivoqué pensé que era libro físico',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Vino en mal estado y me esta costando que me hagan...',
#   'full_text': 'Vino en mal estado y me esta costando que me hagan la devolucion',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No mandan el balón que describen...',
#   'full_text': 'No mandan el balón que describen...',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No es lo que esperaba',
#   'full_text': 'No es lo que esperaba',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'El protector solo se adhiere a la parte central de...',
#   'full_text': 'El protector solo se adhiere a la parte central de la pantalla, los bordes quedan totalmente despegados.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No era lo que pensaba',
#   'full_text': 'No era lo que pensaba',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Como podréis apreciar anzuelos oxidados así como t...',
#   'full_text': 'Como podréis apreciar anzuelos oxidados así como textura pasada y descolorida.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No realiza las expectativas, no ahuyenta',
#   'full_text': 'No realiza las expectativas, no ahuyenta',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Difícil de actualizar y poco preciso.',
#   'full_text': 'Difícil de actualizar y poco preciso.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'se rompio la primera semana',
#   'full_text': 'se rompio la primera semana',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Barato y poco funcional',
#   'full_text': 'Barato y poco funcional',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Muy malo se rompe enseguida',
#   'full_text': 'Muy malo se rompe enseguida',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Vinieron varias rotas',
#   'full_text': 'Vinieron varias rotas',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Ha llegado en mal estado',
#   'full_text': 'Ha llegado en mal estado',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me llegó sin enchufe',
#   'full_text': 'Me llegó sin enchufe',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me estropeó el iphone',
#   'full_text': 'Me estropeó el iphone',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Malísima calidad, camiseta superfina.',
#   'full_text': 'Malísima calidad, camiseta superfina.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Para poder dar mi opinion me lo deberian haber env...',
#   'full_text': 'Para poder dar mi opinion me lo deberian haber enviado y todavia despues de casi mes y medio no ha llegado',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Es diferente al de la foto.',
#   'full_text': 'Es diferente al de la foto.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No hacen mucho efecto',
#   'full_text': 'No hacen mucho efecto',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'En la foto se ve blanco pero en realidad es gris',
#   'full_text': 'En la foto se ve blanco pero en realidad es gris',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'me paro con 2 meses de uso',
#   'full_text': 'me paro con 2 meses de uso',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No era lo que esperaba',
#   'full_text': 'No era lo que esperaba',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Me biene sin pilas y no funciona',
#   'full_text': 'Me biene sin pilas y no funciona',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Defectuosos, mal pintados y con golpes.',
#   'full_text': 'Defectuosos, mal pintados y con golpes.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Se despega no vale para nada',
#   'full_text': 'Se despega no vale para nada',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Dejo de funcionar al segundo mes',
#   'full_text': 'Dejo de funcionar al segundo mes',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Totalmente decepcionada! En La foto sale Iron Man ...',
#   'full_text': 'Totalmente decepcionada! En La foto sale Iron Man brillante y el que he recibido es completamente mate. No es igual.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'La pantalla se enciende y se apaga a su antojo, un...',
#   'full_text': 'La pantalla se enciende y se apaga a su antojo, un desastre!',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No funcionan, la impresora dice que son piratas y ...',
#   'full_text': 'No funcionan, la impresora dice que son piratas y no imprime.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'No se corresponde con lo que pedi',
#   'full_text': 'No se corresponde con lo que pedi',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Se acaban las pilas en un segundo',
#   'full_text': 'Se acaban las pilas en un segundo',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Instrucciones en Inglés.',
#   'full_text': 'Instrucciones en Inglés.',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  {'text': 'Le faltaba las pegatinas',
#   'full_text': 'Le faltaba las pegatinas',
#   'language': 'Unknown',
#   'code': 'un',
#   'rating': 0,
#   'confidence': 0,
#   'reliable': False},
#  ...]

# %%
print("\n" + "="*80)
print("DETECTION STATISTICS & INSIGHTS")
print("="*80 + "\n")

all_detections = analyzer.detection_details + analyzer.detection_details

# Count by detection method
method_counts = {}
for detail in all_detections:
    method = detail.get('detection_method', 'unknown')
    method_counts[method] = method_counts.get(method, 0) + 1

print("Detection Methods Used:")
for method, count in sorted(method_counts.items(), key=lambda x: x[1], reverse=True):
    percentage = (count / len(all_detections)) * 100
    print(f"  {method}: {count} times ({percentage:.1f}%)")

# Average confidence by language
print("\nAverage Confidence by Language:")
lang_confidence = {}
for detail in all_detections:
    lang = detail['language']
    if lang not in lang_confidence:
        lang_confidence[lang] = []
    lang_confidence[lang].append(detail['confidence'])

for lang, confidences in sorted(lang_confidence.items()):
    avg_conf = sum(confidences) / len(confidences)
    print(f"  {lang}: {avg_conf:.1f}% (from {len(confidences)} review(s))")

print("\n" + "="*80)
print("="*80)
# Out:
# ================================================================================
# DETECTION STATISTICS & INSIGHTS
# ================================================================================
#
# Detection Methods Used:
#   unknown: 2400000 times (100.0%)
#
# Average Confidence by Language:
#   CATALAN: 96.3% (from 128 review(s))
#   CORSICAN: 96.5% (from 4 review(s))
#   CZECH: 96.0% (from 2 review(s))
#   Chinese: 97.7% (from 389484 review(s))
#   ChineseT: 91.5% (from 1418 review(s))
#   DANISH: 95.9% (from 186 review(s))
#   DUTCH: 96.3% (from 30 review(s))
#   ENGLISH: 98.3% (from 403722 review(s))
#   ESPERANTO: 96.0% (from 2 review(s))
#   ESTONIAN: 95.0% (from 2 review(s))
#   FINNISH: 96.0% (from 2 review(s))
#   FRENCH: 98.4% (from 391052 review(s))
#   FRISIAN: 97.0% (from 2 review(s))
#   GALICIAN: 97.2% (from 314 review(s))
#   GERMAN: 98.6% (from 398404 review(s))
#   GREEK: 16.3% (from 6 review(s))
#   GUARANI: 96.0% (from 6 review(s))
#   HAITIAN_CREOLE: 95.5% (from 4 review(s))
#   INDONESIAN: 96.4% (from 418 review(s))
#   INTERLINGUA: 96.2% (from 20 review(s))
#   INTERLINGUE: 96.3% (from 6 review(s))
#   ITALIAN: 96.8% (from 68 review(s))
#   Japanese: 98.1% (from 400068 review(s))
#   KINYARWANDA: 97.0% (from 2 review(s))
#   LATIN: 96.1% (from 32 review(s))
#   LATVIAN: 96.0% (from 2 review(s))
#   LINGALA: 95.0% (from 4 review(s))
#   LITHUANIAN: 96.0% (from 2 review(s))
#   LUXEMBOURGISH: 95.8% (from 70 review(s))
#   MALAY: 95.5% (from 4 review(s))
#   MALTESE: 95.0% (from 2 review(s))
#   MAORI: 95.0% (from 4 review(s))
#   NAURU: 96.0% (from 6 review(s))
#   NORWEGIAN: 96.0% (from 2 review(s))
#   NORWEGIAN_N: 96.4% (from 46 review(s))
#   OCCITAN: 96.8% (from 50 review(s))
#   PORTUGUESE: 96.8% (from 350 review(s))
#   RHAETO_ROMANCE: 96.3% (from 44 review(s))
#   ROMANIAN: 96.0% (from 8 review(s))
#   SAMOAN: 96.7% (from 6 review(s))
#   SCOTS: 95.7% (from 28 review(s))
#   SERBIAN: 96.0% (from 6 review(s))
#   SESELWA: 95.9% (from 46 review(s))
#   SISWANT: 96.0% (from 2 review(s))
#   SLOVAK: 95.4% (from 10 review(s))
#   SPANISH: 98.4% (from 386360 review(s))
#   UZBEK: 97.0% (from 2 review(s))
#   Unknown: 0.0% (from 27400 review(s))
#   VOLAPUK: 96.0% (from 2 review(s))
#   WARAY_PHILIPPINES: 95.3% (from 152 review(s))
#   WOLOF: 96.2% (from 8 review(s))
#   ZHUANG: 94.0% (from 2 review(s))
#
# ================================================================================
# ================================================================================

# %%
def export_analysis_to_csv(analyzer, filename='review_analysis.csv', allow_overwrite=False):
    """
    Export detailed analysis to CSV with enhanced features and error handling
    
    Args:
        analyzer: FastReviewAnalyzer instance
        filename: Target filename (supports .csv or .xlsx)
        allow_overwrite: If False, will not overwrite existing files
    """
    import os
    from datetime import datetime
    
    # Validate analyzer
    if not hasattr(analyzer, 'detection_details') or not analyzer.detection_details:
        raise ValueError("No analysis results to export!")
    
    # Validate and adjust filename
    if not filename.lower().endswith(('.csv', '.xlsx')):
        filename += '.csv'
    
    # Check if file exists
    if os.path.exists(filename) and not allow_overwrite:
        base, ext = os.path.splitext(filename)
        filename = f"{base}_{datetime.now().strftime('%Y%m%d_%H%M%S')}{ext}"
        print(f"File already exists. Saving as: {filename}")
    
    try:
        total_rows = len(analyzer.detection_details)
        print(f"\nPreparing to export {total_rows:,} reviews...")
        
        # Prepare data with validation
        export_data = []
        for detail in analyzer.detection_details:
            if not isinstance(detail, dict):
                continue
                
            export_data.append({
                'Review Text': detail.get('full_text', ''),
                'Language': detail.get('language', 'Unknown'),
                'Language Code': detail.get('code', 'unknown'),
                'Rating': float(detail.get('rating', 0)),
                'Confidence %': round(float(detail.get('confidence', 0)), 1),
                'Detection Method': detail.get('detection_method', 'unknown'),
                'Reliable': 'Yes' if detail.get('reliable', False) else 'No',
                'Text Length': len(str(detail.get('full_text', ''))),
                'Export Date': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            })
        
        # Export based on file format
        if filename.lower().endswith('.xlsx'):
            import pandas as pd
            df = pd.DataFrame(export_data)
            df.to_excel(filename, index=False)
        else:
            import csv
            with open(filename, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=export_data[0].keys())
                writer.writeheader()
                
                for i, row in enumerate(export_data, 1):
                    writer.writerow(row)
                    if i % 5000 == 0:
                        print(f"Progress: {i:,}/{total_rows:,} ({i/total_rows*100:.1f}%)")
        
        print(f"\n✓ Successfully exported {total_rows:,} reviews to {filename}")
        print(f"  File size: {os.path.getsize(filename):,} bytes")
        
    except Exception as e:
        print(f"\n❌ Error during export: {str(e)}")
        raise

# Example usage
  # Export as Excel
# OR
export_analysis_to_csv(analyzer, 'review_analysis.csv')   # Export as CSV
# Out:
# File already exists. Saving as: review_analysis_20251005_140015.csv
#
# Preparing to export 1,200,000 reviews...
# Progress: 5,000/1,200,000 (0.4%)
# Progress: 10,000/1,200,000 (0.8%)
# Progress: 15,000/1,200,000 (1.2%)
# Progress: 20,000/1,200,000 (1.7%)
# Progress: 5,000/1,200,000 (0.4%)
# Progress: 10,000/1,200,000 (0.8%)
# Progress: 15,000/1,200,000 (1.2%)
# Progress: 20,000/1,200,000 (1.7%)
# Progress: 25,000/1,200,000 (2.1%)
# Progress: 30,000/1,200,000 (2.5%)
# Progress: 35,000/1,200,000 (2.9%)
# Progress: 25,000/1,200,000 (2.1%)
# Progress: 30,000/1,200,000 (2.5%)
# Progress: 35,000/1,200,000 (2.9%)
# Progress: 40,000/1,200,000 (3.3%)
# Progress: 45,000/1,200,000 (3.8%)
# Progress: 50,000/1,200,000 (4.2%)
